# %%
# prompt: import the file https://docs.google.com/spreadsheets/d/1o7bLfOYgDyA1Xy73QdqMwdpxLrgO6SN4zQ4VnyMJ500/edit?usp=drive_link from gdrive

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

spreadsheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1o7bLfOYgDyA1Xy73QdqMwdpxLrgO6SN4zQ4VnyMJ500/edit?usp=drive_link')

# To read a specific worksheet, replace 'Sheet1' with the actual sheet name
worksheet = spreadsheet.worksheet('Captured Texts')

# Get all of the values from the worksheet as a list of lists
rows = worksheet.get_all_values()

# Print the data (optional)
# for row in rows:
#   print(row)

# You can convert it to a pandas DataFrame if needed
import pandas as pd
df = pd.DataFrame(rows[1:], columns=rows[0])
df
# Out:
#                Date (GMT)                                           Job Link  \
# 0     2025-06-15 11:22:56  https://dashboard.browse.ai/workspaces/levente...
# 1     2025-06-15 18:04:42  https://dashboard.browse.ai/workspaces/levente...
# 2     2025-06-16 08:59:54  https://dashboard.browse.ai/workspaces/levente...
# 3     2025-06-16 09:10:17  https://dashboard.browse.ai/workspaces/levente...
# 4     2025-06-16 09:10:17  https://dashboard.browse.ai/workspaces/levente...
# ...                   ...                                                ...
# 2004  2025-06-16 09:32:06  https://dashboard.browse.ai/workspaces/levente...
# 2005  2025-06-16 09:32:06  https://dashboard.browse.ai/workspaces/levente...
# 2006  2025-06-16 09:32:08  https://dashboard.browse.ai/workspaces/levente...
# 2007  2025-06-16 09:32:08  https://dashboard.browse.ai/workspaces/levente...
# 2008  2025-06-16 09:32:36  https://dashboard.browse.ai/workspaces/levente...
#
#                                              Origin URL  \
# 0     https://www.whisky.de/shop/en/product/Jura-Red...
# 1     https://www.whisky.de/shop/en/product/Aberlour...
# 2     https://www.whisky.de/shop/en/product/Jura-Red...
# 3     https://www.whisky.de/shop/en/product/Lagavuli...
# 4     https://www.whisky.de/shop/en/product/Glenfarc...
# ...                                                 ...
# 2004  https://www.whisky.de/shop/en/product/Bowmore-...
# 2005  https://www.whisky.de/shop/en/product/Rothaus-...
# 2006  https://www.whisky.de/shop/en/product/North-Br...
# 2007  https://www.whisky.de/shop/en/product/Invergor...
# 2008  https://www.whisky.de/shop/en/product/Dalmunac...
#
#                                                    Name Average_score  \
# 0                             Jura Red Wine Cask Finish           3.8
# 1              Aberlour 48% Non Chill-Filtered 12 Years           4.3
# 2                             Jura Red Wine Cask Finish           3.8
# 3                                    Lagavulin 16 Years           4.5
# 4                                  Glenfarclas 25 Years           4.6
# ...                                                 ...           ...
# 2004                      Bowmore - new design 15 Years
# 2005                       Rothaus Black Forest Banyuls
# 2006  North British Murça Tawny Port & Ximénez-Spíno...
# 2007  Invergordon Ex-Islay Cask Finish - Select Grai...
# 2008  Dalmunach First Fill Sherry & Wine Firkin + PX...             4
#
#      Number_of_reviewers                                      Taste_profile  \
# 0                     70             Taste profile\n Fruit\n Sweet\n Sherry
# 1                    309             Taste profile\n Sherry\n Fruit\n Sweet
# 2                     70             Taste profile\n Fruit\n Sweet\n Sherry
# 3                   1607  Taste profile\n Peat Smoke\n Seaweed\n Maritim...
# 4                    582               Taste profile\n Sherry\n Oak\n Sweet
# ...                  ...                                                ...
# 2004                            Taste profile\n Peat Smoke\n Sweet\n Sherry
# 2005                      Taste profile\n Nutmeg\n Fruit\n Caramel\n Sherry
# 2006                          Taste profile\n Oil\n Nuts\n Berries\n Sherry
# 2007                            Taste profile\n Clove\n Peat Smoke\n Spices
# 2008                   1         Taste profile\n Chocolate\n Sweet\n Sherry
#
#                   Variety                                              Aroma  \
# 0      Single Malt Whisky  Sultanas, creamy caramel and black forest cake...
# 1      Single Malt Whisky  Full and fruity, distantly reminiscent of stra...
# 2      Single Malt Whisky  Sultanas, creamy caramel and black forest cake...
# 3      Single Malt Whisky  Intense peat smoke with notes of iodine and se...
# 4      Single Malt Whisky  Jam, honey and a little coffee melt into sherr...
# ...                   ...                                                ...
# 2004   Single Malt Whisky  Dark chocolate, sun-dried fruit and a hint of ...
# 2005   Single malt whisky  Warm woody notes and dark dried fruit combine ...
# 2006  Single Grain Whisky  Fruity compote notes with accents of berries a...
# 2007  Single Grain Whisky  Honey and oat notes combine with smoky vanilla...
# 2008   Single Malt Whisky  Facets of berry purée with notes of chocolate ...
#
#                                                   Taste  ...   Volume  \
# 0     Red wine with a hint of raspberries and strawb...  ...  0,7 l ·
# 1     Strong sherry notes and ripe fruit followed by...  ...  0,7 l ·
# 2     Red wine with a hint of raspberries and strawb...  ...  0,7 l ·
# 3     Dry peat smoke fills the palate with a gentle ...  ...  0,7 l ·
# 4     Sherry and oak have the upper hand. Wonderfull...  ...  0,7 l ·
# ...                                                 ...  ...      ...
# 2004    Marvellous cedar wood and strong caramel syrup.  ...  0,7 l ·
# 2005  Fruity, sweet with strong wine notes, plus gen...  ...  0,5 l ·
# 2006        Creamy with notes of jam and caramel sauce.  ...  0,7 l ·
# 2007  Baked apple, cloves and grassy notes embedded ...  ...  0,7 l ·
# 2008                                           Speyside  ...  0,7 l ·
#
#      Alcohol_content Full_price Action_price  \
# 0           40 % vol                 29,90 €
# 1           48 % vol                 21,90 €
# 2           40 % vol                 29,90 €
# 3           43 % vol                 49,90 €
# 4           43 % vol                198,00 €
# ...              ...        ...          ...
# 2004        43 % vol                 86,90 €
# 2005      55,9 % vol                 59,90 €
# 2006      51,7 % vol                 59,90 €
# 2007      49,5 % vol                 49,90 €
# 2008      57,2 % vol                 69,90 €
#
#                        Contains_colouring  \
# 0     Contains colouring: Caramel color ·
# 1     Contains colouring: Caramel color ·
# 2     Contains colouring: Caramel color ·
# 3     Contains colouring: Caramel color ·
# 4                              282,86 €/l
# ...                                   ...
# 2004  Contains colouring: Caramel color ·
# 2005                           119,80 €/l
# 2006                            85,57 €/l
# 2007                            71,29 €/l
# 2008                            99,86 €/l
#
#                                     Product description  \
# 0     This Jura was first matured in former bourbon ...
# 1     The Aberlour Non Chill-Filtered differs from t...
# 2     This Jura was first matured in former bourbon ...
# 3     Lagavulin's classic is kilned with a high smok...
# 4     This Glenfarclas matures for a quarter of a ce...
# ...                                                 ...
# 2004  After maturing in bourbon casks, the extremely...
# 2005  Rothaus Black Forest Banyuls Finish spent its ...
# 2006  This 13-year-old North British was bottled by ...
# 2007  This Invergordon Single Grain was bottled by M...
# 2008  The casks for the maturation of the 8-year-old...
#
#                          Distillery Distillery_status  \
# 0      The Distillery: Isle of Jura              Open
# 1          The Distillery: Aberlour              Open
# 2      The Distillery: Isle of Jura              Open
# 3         The Distillery: Lagavulin              Open
# 4       The Distillery: Glenfarclas              Open
# ...                             ...               ...
# 2004        The Distillery: Bowmore              Open
# 2005        The Distillery: Rothaus              Open
# 2006  The Distillery: North British              Open
# 2007    The Distillery: Invergordon              Open
# 2008      The Distillery: Dalmunach              Open
#
#      Distillery_founding_year             Distillery_country_region
# 0                        1810    Country, Region\nScotland, Islands
# 1                        1826   Country, Region\nScotland, Speyside
# 2                        1810    Country, Region\nScotland, Islands
# 3                        1816      Country, Region\nScotland, Islay
# 4                        1836   Country, Region\nScotland, Speyside
# ...                       ...                                   ...
# 2004                     1779      Country, Region\nScotland, Islay
# 2005                     1791              Country, Region\nGermany
# 2006                     1885   Country, Region\nScotland, Lowlands
# 2007                     1960  Country, Region\nScotland, Highlands
# 2008                     2015   Country, Region\nScotland, Speyside
#
# [2009 rows x 23 columns]

# %%
df.drop(columns=["Region"], inplace=True)

# %%
# prompt: replace , to . in the column Action_price, if more than one . are in there, keep only the last,  replace € mark to nothing, cast to float

df['Action_price'] = df['Action_price'].str.replace('€', '', regex=False)
df['Action_price'] = df['Action_price'].str.replace('.', '', regex=False)
df['Action_price'] = df['Action_price'].str.replace(',', '.', regex=False)
df['Action_price'] = pd.to_numeric(df['Action_price'])

# %%
# prompt: if for a single row the column Contains_colouring has the € sign in it, copy it's content to the column Full_price, and delete it from the column Contains_colouring

for index, row in df.iterrows():
    if '€' in row['Contains_colouring']:
        #df.loc[index, 'Full_price'] = row['Contains_colouring']
        df.loc[index, 'Contains_colouring'] = ''

# %%
# prompt: if the column Contains_colouring has a non empty string, then make it bool true, if empty, bool false

df['Contains_colouring'] = df['Contains_colouring'].apply(lambda x: bool(x.strip()))

# %%
# prompt: drop column Full_price

df = df.drop('Full_price', axis=1)
df = df.drop('Job Link', axis=1)
df = df.drop('Date (GMT)', axis=1)

# %%
# prompt: Average_score should be casted to float, if empty string, then to 0

df['Average_score'] = df['Average_score'].apply(lambda x: float(x) if x else 0.0)
df['Number_of_reviewers'] = df['Number_of_reviewers'].apply(lambda x: float(x) if x else 0.0)

# %%
df["Taste_profile"] = df["Taste_profile"].str.replace("Taste profile\n", "")

# %%
df["Taste_list"] = (
    df["Taste_profile"]
    .str.split(r"\s*\\n\s*")          # split on the literal “\n”
    .apply(lambda lst: [t.strip() for t in lst if t.strip()])
)
df["Taste_sentence"] = df["Taste_list"].apply(", ".join)

# %% [markdown]
# Original idea: https://chatgpt.com/share/684fef18-8560-8001-a94b-f1ca4d21fa0e

# %%
# prompt: df["Taste_profile"] drop column

df = df.drop("Taste_profile", axis=1)

# %%
df.Variety.value_counts()
# Out:
# Variety
# Single Malt Whisky           1161
# Single malt whisky            255
# Kentucky Straight Bourbon      94
# Single Malt Whiskey            67
# Blended Whisky                 58
# Blended Malt Whisky            50
# Blended whisky                 46
# Blended Whiskey                44
# Rye                            30
# Blended whiskey                26
# Single Grain Whisky            21
# Single Pot Still Whiskey       21
# Single malt whiskey            16
# Straight Rye                   16
# Tennessee Whiskey              13
# Blended malt whisky            11
# Kentucky Straight Rye          10
# Bourbon                         8
# Single Grain Whiskey            7
# Whisky                          6
# Straight Bourbon                6
# Whiskey                         5
# Single pot still whiskey        3
# Straight Corn                   3
# Kentucky Bourbon                2
# Grain Whiskey                   2
# Corn                            2
# Single grain whisky             2
# Distillate (spirit)             2
# Single grain whiskey            2
# Tennessee Straight Rye          2
# Grain Whisky                    2
# Blended Malt Whiskey            1
# Pot Still Whiskey               1
# Wheat Whisky                    1
# Kentucky Straight Malt          1
# Blended Rye Whisky              1
# Wheat whisky                    1
# Sour Mash Whisky                1
# Rum-based spirit                1
# Liqueur                         1
# Single pot still whisky         1
# Tennessee Rye Whiskey           1
# Gin                             1
# Rye whisky                      1
# London Dry Gin                  1
# Blended grain whisky            1
# Distillate (Spirit)             1
# Name: count, dtype: int64

# %%
# prompt: unify the strings of the column Variety to all smallcaps

df['Variety'] = df['Variety'].str.lower()

# %%
# prompt: replace all whisky and whiskey in Variety to none and strip the string

df['Variety'] = df['Variety'].str.replace('whisky', '', regex=False)
df['Variety'] = df['Variety'].str.replace('whiskey', '', regex=False)
df['Variety'] = df['Variety'].str.strip()
#df['Variety'] = df['Variety'].str.replace('', 'unknown', regex=False)

# %%
# prompt: replace empty string  or single space in Variety to unknown

df['Variety'] = df['Variety'].apply(lambda x: 'unknown' if x.strip() == '' else x)

# %%
# prompt: drop rows if column Variety has rum, gin, distillate or liqueur in it, even if any of these has no space after it

df = df[~df['Variety'].str.contains('rum|gin|distillate|liqueur')]

# %%
# prompt: replace % vol in Alcohol_content, cast it to float and rename the colun to Alcohol_content_percent

df['Alcohol_content_percent'] = df['Alcohol_content'].str.replace('% vol', '', regex=False)
df['Alcohol_content_percent'] = df['Alcohol_content_percent'].str.replace(',', '.', regex=False)

df['Alcohol_content_percent'] = df['Alcohol_content_percent'].astype(float)
df = df.drop('Alcohol_content', axis=1)
# Out:
# <ipython-input-16-3572085328>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alcohol_content_percent'] = df['Alcohol_content'].str.replace('% vol', '', regex=False)
# <ipython-input-16-3572085328>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alcohol_content_percent'] = df['Alcohol_content_percent'].str.replace(',', '.', regex=False)
# <ipython-input-16-3572085328>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alcohol_content_percent'] = df['Alcohol_content_percent'].astype(float)

# %%
# prompt: replace Please select to unknown in the column Distillery_status as well as Torn down to Closed, empty string to unknown

df['Distillery_status'] = df['Distillery_status'].replace({
    'Please select': 'unknown',
    'Torn down': 'Closed',
    '': 'Closed'  # Replacing empty strings
})

# %%
# prompt: replace Products with similar taste	in Distillery to unknown, the string The Distillery: to nothing in all rows, and ig empty string remains, to unknown

df['Distillery'] = df['Distillery'].str.replace('Products with similar taste', 'unknown', regex=False)
df['Distillery'] = df['Distillery'].str.replace('The Distillery:', '', regex=False)
df['Distillery'] = df['Distillery'].apply(lambda x: 'unknown' if x.strip() == '' else x)

# %%
# prompt: replace Distillery_founding_year empty to nan and cast to integer

import numpy as np

df['Distillery_founding_year'] = df['Distillery_founding_year'].replace('', np.nan)
df['Distillery_founding_year'] = df['Distillery_founding_year'].astype('Int64')

# %%
# prompt: replace Country, Region\n in Distillery_country_region to  ''

df["Distillery_country_region"] = df["Distillery_country_region"].str.replace("Country, Region\n", "", regex=False)

# %%
# prompt: split Distillery_country_region on , make a new column Country from the first part stripped and a Column Region from the second, stripped, if second is missing, leave the region empty, drop original column

df[['Country', 'Region']] = df['Distillery_country_region'].str.split(',', expand=True)
df['Country'] = df['Country'].str.strip()
df['Region'] = df['Region'].str.strip()
df['Region'] = df['Region'].fillna('') # Fill NaN with empty string for cases with no region
df = df.drop('Distillery_country_region', axis=1)

# %%
df.Region.value_counts()
# Out:
# Region
#                     698
# Speyside            423
# Highlands           321
# Islay               191
# Kentucky            113
# Islands             109
# Lowlands             66
# Campbeltown          26
# Tennessee            22
# British Columbia      8
# Texas                 6
# Region                5
# Illinois              4
# Vermont               4
# Maryland              2
# Oregon                1
# Iowa                  1
# Virginia              1
# Indiana               1
# Name: count, dtype: int64

# %%
# prompt: split on first space the column Volume, then replace , to . and cast to float

df['Volume'] = df['Volume'].str.split(' ', n=1, expand=True)[0]
df['Volume'] = df['Volume'].str.replace(',', '.', regex=False)
df['Volume'] = df['Volume'].astype(float)

# %%
df.Volume.value_counts()
# Out:
# Volume
# 0.70    1827
# 1.00      71
# 0.50      52
# 0.20      18
# 2.10       7
# 0.05       7
# 0.75       5
# 2.80       2
# 0.60       2
# 0.35       2
# 0.12       2
# 1.40       2
# 0.80       1
# 0.15       1
# 1.75       1
# 0.08       1
# 0.04       1
# Name: count, dtype: int64

# %% [markdown]
#  'Aroma', 'Taste',
#        'Finish', 'Maturation', 'Product description'
#
#
# MAybe region is fucked up into the Taste?

# %%
df.Maturation
# Out:
# 0           Ex-bourbon casks and finish in red wine casks
# 1
# 2           Ex-bourbon casks and finish in red wine casks
# 3                                Bourbon and sherry casks
# 4                                    Oloroso sherry casks
#                               ...
# 2004     Bourbon casks and finish in Oloroso sherry casks
# 2005
# 2006    Hogsheads, finish in first fill Murça port cas...
# 2007                             Finish in ex Islay casks
# 2008
# Name: Maturation, Length: 2002, dtype: object

# %%
df['Product description']
# Out:
# 0       This Jura was first matured in former bourbon ...
# 1       The Aberlour Non Chill-Filtered differs from t...
# 2       This Jura was first matured in former bourbon ...
# 3       Lagavulin's classic is kilned with a high smok...
# 4       This Glenfarclas matures for a quarter of a ce...
#                               ...
# 2004    After maturing in bourbon casks, the extremely...
# 2005    Rothaus Black Forest Banyuls Finish spent its ...
# 2006    This 13-year-old North British was bottled by ...
# 2007    This Invergordon Single Grain was bottled by M...
# 2008    The casks for the maturation of the 8-year-old...
# Name: Product description, Length: 2002, dtype: object

# %%
# prompt: save the df back to Google drive under the name "Whisky.de details - cleaned" as csv. if exists, overwrite.

from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define the path to save the CSV file in your Drive
file_path = '/content/drive/My Drive/Whisky.de details - cleaned.csv'

# Save the DataFrame to a CSV file, overwriting if it exists
df.to_csv(file_path, index=False, encoding='utf-8')

print(f"DataFrame saved to {file_path}")
# Out:
# Mounted at /content/drive
# DataFrame saved to /content/drive/My Drive/Whisky.de details - cleaned.csv
